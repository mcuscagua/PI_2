# %%
import pandas as pd

# %%
Features = pd.read_csv('Features.csv')

# %%
Features
# Out:
#             Date  DXY Curncy  EUR Curncy  GT10 Govt  GT2 Govt  GT5 Govt  \
# 0       1/3/2000     100.220      1.0243      6.592     6.384     6.502
# 1       1/4/2000     100.410      1.0296      6.497     6.299     6.398
# 2       1/5/2000     100.380      1.0321      6.594     6.358     6.483
# 3       1/6/2000     100.480      1.0328      6.524     6.299     6.418
# 4       1/7/2000     100.720      1.0295      6.515     6.308     6.411
# 5      1/10/2000     100.990      1.0256      6.552     6.359     6.461
# 6      1/11/2000     100.560      1.0336      6.657     6.428     6.554
# 7      1/12/2000     100.620      1.0309      6.703     6.472     6.605
# 8      1/13/2000     101.000      1.0258      6.630     6.394     6.528
# 9      1/14/2000     101.720      1.0122      6.679     6.430     6.576
# 10     1/17/2000     101.770      1.0122      6.681     6.430     6.576
# 11     1/18/2000     101.860      1.0137      6.748     6.465     6.623
# ...
